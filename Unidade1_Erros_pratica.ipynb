# %% [markdown]
# <a href="https://colab.research.google.com/github/pccalegari/exemplos-CN/blob/main/Unidade1_Erros_pratica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução e Erros
#
# Na aula passada, conversamos sobre os diferentes tipos de erro (iniciais, truncamento e arredondamento) envolvidos durante a solução de um problema por meio de métodos numéricos. Vamos discutir um pouco mais sobre o erro de arredondamento e na sequência, implementar e analisar as soluções aproximadas de alguns problemas.
#
# * **Erros na representação dos números**
#
# São os erros associados à representação do sistema de numeração da máquina.
# A maioria das máquinas trabalha com o sistema binário. Dessa forma, vamos discutir sobre a a representação de números inteiros e a representação de números reais.
#
# *Representação de números inteiros*:
#
# Um número inteiro na base binária é representado pelos coeficientes de sua expansão binária. Por exemplo,
#
# $13 = 1\times 2^3 + 1\times 2^2 + 0\times 2^1 + 1\times 2^0,$ ou seja, $13 = (1101)_2$.
#
# *Representação de números reais:*
#
# Na base decimal, representamos os números reais,
# $$N = a_n10^n+\ldots+a_110^1+a_010^0+a_{-1}10^{-1}+\ldots+a_{-m}10^{-m},$$
# com $0\le a_i\le 9$.
#
# Da mesma forma, para qualquer base $b\ge 2$, temos
# $$N=\alpha_nb^n+\ldots+\alpha_1b^1+\alpha_0b^0+\alpha_{-1}b^{-1}+\ldots+\alpha_{-m}b^{-m},$$
# com $0\le \alpha_i < b$.
#
# **Exemplo 1.**   $9.625=(1001.101)_2$ pois $9.625=1\times 2^3+0\times 2^2 + 0\times 2^1 + 1\times 2^0+1\times 2^{-1} + 0\times 2^{-2}+1\times 2^{-3}$.
#
# * *Aritmética de ponto flutuante:*
#
# A Aritmética de ponto flutuante é utilizada em cálculos científicos, padronizada para a representação de números reais. A representação é definida pela base, pela quantidade de algarismos significativos e pelo expoente. A representação de um número $x$ em ponto flutuante, na base $b$, com $n$ algarismos significativos e expoente $e$ é dada por:
#
# $$fl(x) = \pm(.a_1a_2\ldots a_n)\times b^e,$$
# sendo $a_1a_2\ldots a_n$ a mantissa do número, com $a_1\neq 0$.
#
# **Exemplo 2.**
#
# (a) Na base decimal os números $0.02531$ e $25.31$, possuem a mesma mantissa e são representados, respectivamente, $0.2531\times 10^{-1}$ e $0.2531\times 10^2$.
#
# (b) Na base binária, dois números consecutivos $0.11100100\times 2^2$ e $0.11100101\times 2^2$, com $8$ algarismos significativos, são respectivamente:
#
# $ 3.5625= \left(\dfrac{1}{2}+\dfrac{1}{2^2}+\dfrac{1}{2^3}+\dfrac{1}{2^6}\right)\times 2^2$ e $3.578125 =  \left(\dfrac{1}{2}+\dfrac{1}{2^2}+\dfrac{1}{2^3}+\dfrac{1}{2^6}+\dfrac{1}{2^8}\right)\times 2^2$
#
# Note que os números entre $3.5625$ e $3.578125$, bem como muitos outros números reais não pode ser representado exatamente.
#
# O mesmo ocorre com qualquer máquina. A representação de um número $x$ em Aritmética de ponto flutuante em um computador com 64 *bits* é dada por:
#
# $$fl(x) = (-1)^{s}2^{c-1023}(1+m),$$
# sendo $s$ o sinal (1 *bit*), $c$ o expoente (11 *bits*) e $m$ a mantissa (52 *bits*).
#
# *Observações:*
#
# * o expoente $c$ com 11 *bits* nos fornece uma variação de $0$ a $2^{11}-1=2047$, que é normalizada de $-1023$ a $1024$.
#
# * Os $52$ *bits* na mantissa equivalem a $16$ algarismos decimais de precisão.
#
# * Em qualquer representação em ponto flutuante temos o menor e o maior número que pode ser representado, indicando *underflow* e o *overflow*.
#
#
#
# **Exemplo 3.** Na representação de 64 *bits* descrita acima, o número
#
# $$0\ 10000000001\ 1011001110001000010000000000000000000000000000000000$$
#
# é positivo pois $s=0$. Os próximos 11 *bits* representam o expoente, um número inteiro, $c = 2^{10} + 1 = 1025$ e $m=2^{-1}+2^{-3}+2^{-4}+2^{-7}+2^{-8}+2^{-9}+2^{-13}+2^{-18}=0.70129776.$ Assim, $fl(x) = 6.80519104$.
#
# **Exemplo 4.** Considere uma máquina que utilize $16$ *bits* sendo $1$ *bit* para armazenar o sinal, $4$ *bits* para o expoente e $11$ *bits* para a mantissa. Descreva informações a respeito da precisão dessa máquina.
#
# Primeiro vamos analisar a variação do expoente. Com 4 *bits* temos $2^4=16$ possibilidades, uma variação de 0 a 15, que após a normalização fica de $-7$ a $8$. Assim, a representação é dada por,
#
# $$(-1)^s2^{c-7}(1+f).$$
#
#
# O menor número representado é: $0\ 0000\ 00000000001 \approx 2^{-7}(1+2^{-11}) = 0.0078163147$. O maior número representado é $0\ 1111 \ 11111111111 \approx 2^8(1+0.9995117188) \approx 512$. A precisão da mantissa $2^{-11}\approx 0.0004882813$.
#
# A quantidade de algarismos significativos permanece fixa ao longo de todos os cálculos. Assim temos duas formas de aproximar a mantissa de um número.
#
# * **Corte**: $.a_1a_2\ldots a_ta_{t+1}\ldots \approx .a_1a_2\ldots a_t$, sendo $t$ a quantidade de algarsimos significativos.
#
# * **Arredondamento**: $.a_1a_2\ldots a_ta_{t+1}\ldots \approx .a_1a_2\ldots \tilde{a_t}$, sendo $t$ a quantidade de algarsimos significativos e $\tilde{a_t}=a_t $ ou $\tilde{a_t}=a_t + 1$, dependendo do resultado de $a_{t+1}+5$.
#
# Um sistema de ponto flutuante pode ser expresso pela função $F(b,n,e_1,e_2)$, onde $b$ é a base, $n$ é a quantidade de algarismos significativos da mantissa e $e_1$ e $e_2$ o menor e o maior expoente, respectivamente.
#
# **Exemplo 5.** Representar os números $1.234$ e $1.235$ usando três algarismos significativos.
#
# Usando o corte temos: $1.23$ em ambos os casos.
#
# Usando o arrendondamento temos:
#
# $1.234$ é representado por $1.23$, pois somando $5$ ao próximo algarismo (o quarto) teremos o número $1.239$ não afetanto o terceiro algarismo.
#
# Já $1.235$ é representado por $1.24$, pois ao somarmos $5$ ao quarto algarismo obtemos $1.240$.
#
# **Exemplo 6.** Realizar as operações usando três algarismos significativos a cada operação aritmética.
#
# Usando arredondamento obtemos:
#
# (4.26+9.24)+5.04 = 13.5 + 5.04 = 18.54 $\approx$ 18.5
#
# 4.26 + (9.24+5.04) = 4.26 + 14.28 $\approx$ 4.26 + 14.3  = 18.56 $\approx$ 18.6
#
# Usando o corte, obtemos:
#
# (4.26+9.24)+5.04 = 13.5 + 5.04 = 18.54 $\approx$ 18.5
#
# 4.26 + (9.24+5.04) = 4.26 + 14.28 $\approx$ 4.26 + 14.2  = 18.46 $\approx$ 18.4

# %% [markdown]
# Agora vamos aos problemas a serem implementados:
#
# **Problema 1.** Aquecimento - Série Geométrica
#
# Aproximar o valor da série geométrica $\displaystyle{\sum_{k=0}^{\infty}a r^k = a + ar^2 + ar^3 + \ldots}$, com $a = 1/3$ e $r = 0.5$. Note que a série geométrica é convergente se $|r|< 1$, dada por $\displaystyle{\dfrac{a}{1-r}}$.

# %% [markdown]
# **Problema 2.** Erro de Truncamento
#
# Dado $x$, calcular uma aproximação para $e^x$ usando a série de Taylor, com $x_0=0$, dada pela expressão,
#
# $$e^x \approx 1 + \sum_{i=1}^{\infty}\dfrac{x^i}{i!}=1 + x + \dfrac{x^2}{2!} + \dfrac{x^3}{3!}+\ldots+\dfrac{x^n}{n!}+\ldots$$
#
# Avalie o erro cometido, experimentando diferentes quantidades de termos para avaliar a série.

# %% [markdown]
# **Problema 3.** Precisão da máquina.
#
# ```
# 1.  p = 1
# 2.  c = 1
# 3.  enquanto (c > 0) faça:
# 4.     p = p/2
# 5.     se (1 + p > 1) então:
# 6.        c = c + 1
# 7.     caso contrário
# 8.        c = 0
# 9.     fim se
# 10. fim enquanto
# 11. escreva p
# ```
#
# Para ver a diferença entre a variável simples (*float* na linguagem C) e a variável com precisão dupla (*double* na linguagem C), vamos utilizar o módulo *numpy*. Este módulo necessita de instalação (mais detalhes veja [numpy](https://numpy.org/)) e para utilizá-lo:
#
#
# ```
# import numpy as np
# ```
#
# Para utilizar a precisão simples vamos usar ``` np.float32() ``` em cada variável real.

# %% [markdown]
# **Problema 4.** Aproximação da derivada.
#
# A partir da Série de Taylor, obtemos uma expressão para aproximar a Derivada de uma função. Este método de aproximação se chama **Diferenças Finitas**.
#
# $$f(x+h) = f(x) + f^{'}(x)h+\dfrac{f^{''}(x)h^2}{2}+\ldots+\dfrac{f^{(n)}(x)h^n}{n!}+\ldots = f(x) + f^{'}(x)h+ O(h^2),$$
#
# $$f'(x) = \dfrac{f(x+h) - f(x)}{h} + O(h),$$
# com $h$ suficientemente pequeno. O erro cometido na aproximação da derivada é $O(h)$, ou seja, menor ou igual a uma constante multiplicada por $h$.
#
# *Verificação Numérica*
#
# Grande parte dos métodos numéricos possui uma ordem de aproximação do erro que depende de $h$, com $h$ suficientemente pequeno. Por exemplo, a aproximação da derivada, vista anteriormente, na notação assintótica é $O(h)$, ordem de aproximação do método é $1$. Isso significa, que o erro diminui na ordem que $h$ diminui.
#
# Suponha que resolvemos um problema com $h$ e que o método utilizado tem ordem de aproximação $p$, ou seja, o erro diminui na ordem que $h^p$ diminui, $O(h^p)$. Repetimos a resolução com $h/2$ e obteremos um erro $O\left(\left(\frac{h}{2}\right)^p\right)$ e continuamos esse processo. Ao analisarmos a razão entre dois erros consecutivos, obtemos:
#
# $$\dfrac{E_h}{E_{\frac{h}{2}}}=\dfrac{O(h^p)}{O((\frac{h}{2})^p)}\approx\dfrac{h^p}{\dfrac{h^p}{2^p}}=2^p.$$
#
# Assim, numericamente verificamos o erro analisando a sequência de razões entre os erros cometidos. Esta sequência de razões deve convergir para $2^p$, onde $p$ é a ordem de aproximação do método numérico.
#
# Escreva um algoritmo para aproximar a derivada e faça a verificação numérica da ordem de aproximação.
#
# Vamos verificar a ordem de aproximação para a aproximação da derivada de $f(x)=\sin(x)$ em $x=0$, começando com $h=0.5$.

# %% [markdown]
# **Problema 5.** Erros e Normas.
#
# Norma 2: $||v||_2=\left(\sum_{i=1}^nv_i^2\right)^{\frac{1}{2}}$
#
# Norma $\infty$: $\displaystyle{||v||_{\infty}=\max_{1\le i\le n}|v_i|}$
#
# Escreva funções que recebam um vetor e calcule a norma $2$ e a norma $\infty$.
